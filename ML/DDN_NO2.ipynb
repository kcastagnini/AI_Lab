# %% [markdown]
# # Machine Learning, DNN for regression
#
# ### Description of the dataset NO2
# The dataset that we are going to use for this lesson was obtained from the StatLib repository. http://lib.stat.cmu.edu/datasets/ (NO2).
# The data are a subsample of 500 observations from a data set that originate in a study where air pollution at a road is related to traffic volume and meteorological variables, collected by the Norwegian Public Roads Administration. The response variable (column 1) consist of hourly values of the logarithm of the concentration of NO2 (particles), measured at Alnabru in Oslo, Norway, between October 2001 and August 2003. The predictor variables (columns 2 to 8) are the logarithm of the number of cars per hour, temperature $2$ meters above ground (degree C), wind speed (meters/second), the temperature difference between $25$ and $2$ meters above ground (degree C), wind direction (degrees between 0 and 360), hour of day and day number from October 1 2001. Submitted by Magne Aldrin (magne.aldrin@nr.no). [28/Jul/04] (19kbytes)
#
#
# Target variable: //cioe che vogliamo dedurre
# - NO2 concentration (log) [lno2]
#
# Features: //i dati che abbiamo
# - log of car per hour [lc]
#
# - temperature 2 meters above the ground (degree C)[t2]
#
# - wind speed (meters/seconds) [ws]
#
# - temperature difference between 25 meters and 2 meters above the ground (degree C) [td25]
#
# - wind direction (degrees between 0 and 360) [wd]
#
# - hour of day [hd] average house occupancy
#
# - day number from Oct. 1 2001 [dn]

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from math import sqrt
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras import metrics

# %% [markdown]
# ### ASSIGNING LABELS TO FEATURES
# We assign the labels to the corresponding columns to have a clean representation of the dataset

# %%
features = ['lc', 't2', 'ws', 'td25', 'wd', 'hd', 'dn']

# %% [markdown]
# ### CREATE THE DNN LARGE NETWORK MODEL
#
#
# <img src="images/DNN-all.png" alt="DNN Model Large" width="500"/>
#
#
# #### Create the network as indicated in the image above. All activation functions should be ReLU. Have a look at the slide for hints on the code to use.

# %%
def create_model_large():
    
    # create model
    model = Sequential()
    model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(30, activation='relu'))
    model.add(Dense(40, activation='relu'))
    model.add(Dense(1))
    
    # Compile model
    model.compile(optimizer ='adam', loss = 'mean_squared_error', metrics =[metrics.mae])
    
    return model

# %% [markdown]
# ### CREATE THE TINY ANN MODEL
#
# #### Create an ANN with 1 layer containing 3 neurons (model tiny), alla activation functions should be ReLU.

# %%
def create_model_tiny():
    # create model
    model = Sequential()
    model.add(Dense(3, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(1))
    
    # Compile model
    model.compile(optimizer ='adam', loss = 'mean_squared_error', metrics =[metrics.mae])
    #your code here	
    return model

# %% [markdown]
# ### CREATE THE SMALL ANN MODEL
#
# #### Create an ANN with 1 layer containing 10 neurons (model small), alla activation functions should be ReLU.

# %%
def create_model_small():
    # create model
    model = Sequential()
    model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(1))
    
    # Compile model
    model.compile(optimizer ='adam', loss = 'mean_squared_error', metrics =[metrics.mae])
    #your code here	
    return model

# %% [markdown]
# ### CREATE THE MEDIUM DNN MODEL
#
# #### Create an DNN with 2 layers containing respectively 10 and 30 neurons (model medium), alla activation functions should be ReLU.

# %%
def create_model_medium():
    # create model
    model = Sequential()  
    model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(30, activation='relu'))
    model.add(Dense(1))
    
    # Compile model
    model.compile(optimizer ='adam', loss = 'mean_squared_error', metrics =[metrics.mae])
    #your code here	
    return model

# %%
####QUIZ MODELS:
#Model 128 nodes:
def create_model_128():
    # create model
    model = Sequential()
    model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(1))
    
    # Compile model
    model.compile(optimizer ='adam', loss = 'mean_squared_error', metrics =[metrics.mae])
    #your code here	
    return model

# %% [markdown]
# ### Evaluating the model
#
# The following functions computes the Root Mean Squared Error and the Normalized Root Mean Squared Error between the groud thruth (real) and inferred (pred) responses.

# %%
def RMSE(real, pred):
    return sqrt(mean_squared_error(real, pred))

def NRMSE(real, pred):
    return sqrt(mean_squared_error(real, pred)/(real.max() - real.min()))

# %% [markdown]
# ### Loading  the data
#
# #### Using the panda library to load data, provide a descriptive summary

# %%
# Load data
df = pd.read_csv('NO2.csv', index_col=False) #data frame

# Descriptive statistics summary
df.describe() #statistiche descrittive
# Out:
#              lno2          lc          t2          ws        td25          wd  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     3.698368    6.973342    0.847400    3.056000    0.149400  143.370400
# std      0.750597    1.087166    6.524636    1.784172    1.065237   86.510213
# min      1.223780    4.127130  -18.600000    0.300000   -5.400000    2.000000
# 25%      3.213862    6.175842   -3.900000    1.675000   -0.200000   72.000000
# 50%      3.848020    7.425360    1.100000    2.800000    0.000000   97.000000
# 75%      4.216930    7.793175    4.900000    4.200000    0.600000  220.000000
# max      6.395090    8.348540   21.100000    9.900000    4.300000  359.000000
#
#                hd          dn
# count  500.000000  500.000000
# mean    12.382000  310.474000
# std      6.802693  200.977754
# min      1.000000   32.000000
# 25%      6.000000  118.750000
# 50%     12.500000  212.000000
# 75%     18.000000  513.000000
# max     24.000000  608.000000

# %% [markdown]
# ### Visualzing the relationships among the features in the data
#
# #### Compute and visualize a correlation matring among the features (using the seaborn library).

# %%
# Correlation matrix
corrmat = df.corr() #per capire come sono correlate le varie features tra loro

# Generate a mask for the upper triangle
matrix = np.triu(corrmat) #matrice di correlazione, dice come varia una variabile X al variare di un'altra variabile Y
#Il coefficiente di correlazione risultante varia da -1 a +1, con -1 che rappresenta una perfetta correlazione negativa, 
#+1 che rappresenta una perfetta correlazione positiva e 0 che rappresenta nessuna correlazione tra le variabili.

f, ax = plt.subplots(figsize=(12, 9))
sns.set(font_scale=1)
sns.heatmap(corrmat, vmin=-1, vmax=1, center= 0, square=True, annot=True, annot_kws={'size': 8}, mask=matrix, fmt='.2g', cmap= 'coolwarm')

plt.show()

# %% [markdown]
# ### Standizing the data
#
# #### Standardize features to have 0 mean, sigma 1 and range between -1 and 1.  Do not standardize the response.

# %%
# Standardizing data
sc= MinMaxScaler(feature_range=(-1,1)) #tutti i dati ora sono tra -1 e 1

for var in features:
    if(var != 'lno2'):
        df[var] = sc.fit_transform(df[var].values.reshape(-1, 1)) #la varianza per tutti i dati e' 1

# %%
#test
#df = df.to_numpy()

#print (type(df))
#print (df.shape)

#for i in range(0, 5):
#    print (df[i])

#y_vals = df[:, 0] #first column
#x_vals = df[:, [1, 2, 3, 4, 5, 6, 7]]

#print ("######################")
#for i in range(0, 5):
#    print (y_vals[i])
#    print (x_vals[i])

#trying to get first column

# %% [markdown]
# ### Preparing the data for training, using validation set approach
#
# #### Remove labels and create the validation set.

# %%
#NumPy representation of the data frame (removing labels)
df = df.to_numpy() #df=df.values #toglie le labels (rimangono solo i dati numberici) #toglie le label dal dataset (rimangono solo i numeri)

#You code below
#dividi freature/predictor dalle risposte
#prima colonna e' la riposta, le altre sono i predictor

#insert your code here #la prima colonna
y = df[:, 0]
#insert your code here #tutte le altre colonne da 1 a 7 (features 2 to 8)
X = df[:, [1, 2, 3, 4, 5, 6, 7]]

seed = 7 #il seed serve per scombinare le righe della matrice
np.random.seed(seed)

# split dataset in 75% for traininig and 25% for testing (500 -> 375,125)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=seed) #il seed serve per fare il shuffle dei dati

# split training in 70% for traininig and 30% for validating (375 -> 300,75)
#la validazione non e' il testing, nella validazione abbiamo la nostra risposta e vogliamo vedere come varia la nostra loss durante il training
#X_train: dataset di training
#y_train: risposta
#X_val, y_val sono il validation data, non e' il testing, e' la parte del training che usiamo solo per fare la validazione
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=seed) #insert your code here

# Model creation (choose between tiny, small, medium and large by using the appropriate function)
#model = create_model_large()
model = create_model_128()

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1024
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 34,177
# Trainable params: 34,177
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Fit the DNN to the data

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150, batch_size=32)
# Out:
# Epoch 1/150
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0328 - mean_absolute_error: 0.1390 - val_loss: 0.4026 - val_mean_absolute_error: 0.4892
# Epoch 2/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0315 - mean_absolute_error: 0.1357 - val_loss: 0.3990 - val_mean_absolute_error: 0.4862
# Epoch 3/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0325 - mean_absolute_error: 0.1341 - val_loss: 0.3983 - val_mean_absolute_error: 0.4891
# Epoch 4/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0350 - mean_absolute_error: 0.1420 - val_loss: 0.4192 - val_mean_absolute_error: 0.4933
# Epoch 5/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0330 - mean_absolute_error: 0.1422 - val_loss: 0.4249 - val_mean_absolute_error: 0.5039
# Epoch 6/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0360 - mean_absolute_error: 0.1464 - val_loss: 0.4094 - val_mean_absolute_error: 0.4864
# Epoch 7/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0276 - mean_absolute_error: 0.1277 - val_loss: 0.3923 - val_mean_absolute_error: 0.4841
# Epoch 8/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0303 - mean_absolute_error: 0.1338 - val_loss: 0.3978 - val_mean_absolute_error: 0.4894
# Epoch 9/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0313 - mean_absolute_error: 0.1359 - val_loss: 0.3958 - val_mean_absolute_error: 0.4862
# Epoch 10/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0408 - mean_absolute_error: 0.1517 - val_loss: 0.4003 - val_mean_absolute_error: 0.4912
# Epoch 11/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0360 - mean_absolute_error: 0.1503 - val_loss: 0.4153 - val_mean_absolute_error: 0.4996
# Epoch 12/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0324 - mean_absolute_error: 0.1359 - val_loss: 0.3979 - val_mean_absolute_error: 0.4850
# Epoch 13/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0278 - mean_absolute_error: 0.1279 - val_loss: 0.4263 - val_mean_absolute_error: 0.5091
# Epoch 14/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0307 - mean_absolute_error: 0.1342 - val_loss: 0.4251 - val_mean_absolute_error: 0.4977
# Epoch 15/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0271 - mean_absolute_error: 0.1233 - val_loss: 0.4108 - val_mean_absolute_error: 0.4976
# Epoch 16/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0247 - mean_absolute_error: 0.1185 - val_loss: 0.4129 - val_mean_absolute_error: 0.4918
# Epoch 17/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0257 - mean_absolute_error: 0.1217 - val_loss: 0.4272 - val_mean_absolute_error: 0.5028
# Epoch 18/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0250 - mean_absolute_error: 0.1209 - val_loss: 0.4025 - val_mean_absolute_error: 0.4879
# Epoch 19/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0238 - mean_absolute_error: 0.1135 - val_loss: 0.3982 - val_mean_absolute_error: 0.4847
# Epoch 20/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0273 - mean_absolute_error: 0.1263 - val_loss: 0.4086 - val_mean_absolute_error: 0.4946
# Epoch 21/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0233 - mean_absolute_error: 0.1133 - val_loss: 0.4057 - val_mean_absolute_error: 0.4912
# Epoch 22/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0218 - mean_absolute_error: 0.1127 - val_loss: 0.4089 - val_mean_absolute_error: 0.4925
# Epoch 23/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0269 - mean_absolute_error: 0.1239 - val_loss: 0.4111 - val_mean_absolute_error: 0.4923
# Epoch 24/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0229 - mean_absolute_error: 0.1168 - val_loss: 0.4035 - val_mean_absolute_error: 0.4881
# Epoch 25/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0298 - mean_absolute_error: 0.1290 - val_loss: 0.3952 - val_mean_absolute_error: 0.4841
# Epoch 26/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0319 - mean_absolute_error: 0.1399 - val_loss: 0.3989 - val_mean_absolute_error: 0.4884
# Epoch 27/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0265 - mean_absolute_error: 0.1272 - val_loss: 0.3995 - val_mean_absolute_error: 0.4905
# Epoch 28/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0363 - mean_absolute_error: 0.1478 - val_loss: 0.3992 - val_mean_absolute_error: 0.4885
# Epoch 29/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0303 - mean_absolute_error: 0.1338 - val_loss: 0.4000 - val_mean_absolute_error: 0.4917
# Epoch 30/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0357 - mean_absolute_error: 0.1476 - val_loss: 0.4008 - val_mean_absolute_error: 0.4917
# Epoch 31/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0257 - mean_absolute_error: 0.1256 - val_loss: 0.4301 - val_mean_absolute_error: 0.5068
# Epoch 32/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0287 - mean_absolute_error: 0.1310 - val_loss: 0.4165 - val_mean_absolute_error: 0.4920
# Epoch 33/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0334 - mean_absolute_error: 0.1384 - val_loss: 0.4241 - val_mean_absolute_error: 0.5046
# Epoch 34/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0326 - mean_absolute_error: 0.1308 - val_loss: 0.3906 - val_mean_absolute_error: 0.4801
# Epoch 35/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0259 - mean_absolute_error: 0.1175 - val_loss: 0.4420 - val_mean_absolute_error: 0.5008
# Epoch 36/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0263 - mean_absolute_error: 0.1275 - val_loss: 0.3895 - val_mean_absolute_error: 0.4871
# Epoch 37/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0228 - mean_absolute_error: 0.1157 - val_loss: 0.4191 - val_mean_absolute_error: 0.4988
# Epoch 38/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0204 - mean_absolute_error: 0.1080 - val_loss: 0.4038 - val_mean_absolute_error: 0.4885
# Epoch 39/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0204 - mean_absolute_error: 0.1074 - val_loss: 0.4003 - val_mean_absolute_error: 0.4864
# Epoch 40/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0187 - mean_absolute_error: 0.1037 - val_loss: 0.4366 - val_mean_absolute_error: 0.5054
# Epoch 41/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0199 - mean_absolute_error: 0.1088 - val_loss: 0.4077 - val_mean_absolute_error: 0.4909
# Epoch 42/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0157 - mean_absolute_error: 0.0931 - val_loss: 0.4163 - val_mean_absolute_error: 0.4931
# Epoch 43/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0179 - mean_absolute_error: 0.1025 - val_loss: 0.3957 - val_mean_absolute_error: 0.4850
# Epoch 44/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0169 - mean_absolute_error: 0.0952 - val_loss: 0.3995 - val_mean_absolute_error: 0.4817
# Epoch 45/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0163 - mean_absolute_error: 0.0929 - val_loss: 0.4189 - val_mean_absolute_error: 0.4949
# Epoch 46/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0157 - mean_absolute_error: 0.0930 - val_loss: 0.4120 - val_mean_absolute_error: 0.4933
# Epoch 47/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0157 - mean_absolute_error: 0.0941 - val_loss: 0.4265 - val_mean_absolute_error: 0.5040
# Epoch 48/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0188 - mean_absolute_error: 0.1067 - val_loss: 0.4227 - val_mean_absolute_error: 0.4973
# Epoch 49/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0182 - mean_absolute_error: 0.1013 - val_loss: 0.4294 - val_mean_absolute_error: 0.5021
# Epoch 50/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0227 - mean_absolute_error: 0.1150 - val_loss: 0.4084 - val_mean_absolute_error: 0.4939
# Epoch 51/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0205 - mean_absolute_error: 0.1073 - val_loss: 0.4092 - val_mean_absolute_error: 0.4925
# Epoch 52/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0211 - mean_absolute_error: 0.1148 - val_loss: 0.3926 - val_mean_absolute_error: 0.4842
# Epoch 53/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0245 - mean_absolute_error: 0.1191 - val_loss: 0.4041 - val_mean_absolute_error: 0.4909
# Epoch 54/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0175 - mean_absolute_error: 0.1013 - val_loss: 0.4194 - val_mean_absolute_error: 0.4948
# Epoch 55/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0165 - mean_absolute_error: 0.0997 - val_loss: 0.4211 - val_mean_absolute_error: 0.4992
# Epoch 56/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0160 - mean_absolute_error: 0.0942 - val_loss: 0.4355 - val_mean_absolute_error: 0.5099
# Epoch 57/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0150 - mean_absolute_error: 0.0908 - val_loss: 0.4195 - val_mean_absolute_error: 0.4963
# Epoch 58/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0166 - mean_absolute_error: 0.0945 - val_loss: 0.4324 - val_mean_absolute_error: 0.5034
# Epoch 59/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0149 - mean_absolute_error: 0.0930 - val_loss: 0.4156 - val_mean_absolute_error: 0.4965
# Epoch 60/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0128 - mean_absolute_error: 0.0829 - val_loss: 0.4422 - val_mean_absolute_error: 0.5066
# Epoch 61/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0151 - mean_absolute_error: 0.0938 - val_loss: 0.3970 - val_mean_absolute_error: 0.4833
# Epoch 62/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0135 - mean_absolute_error: 0.0850 - val_loss: 0.4131 - val_mean_absolute_error: 0.4904
# Epoch 63/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0125 - mean_absolute_error: 0.0838 - val_loss: 0.4065 - val_mean_absolute_error: 0.4918
# Epoch 64/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0174 - mean_absolute_error: 0.0946 - val_loss: 0.4402 - val_mean_absolute_error: 0.5085
# Epoch 65/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0205 - mean_absolute_error: 0.1088 - val_loss: 0.4181 - val_mean_absolute_error: 0.5008
# Epoch 66/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0171 - mean_absolute_error: 0.0994 - val_loss: 0.4146 - val_mean_absolute_error: 0.4913
# Epoch 67/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0143 - mean_absolute_error: 0.0883 - val_loss: 0.4271 - val_mean_absolute_error: 0.5008
# Epoch 68/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0140 - mean_absolute_error: 0.0874 - val_loss: 0.4139 - val_mean_absolute_error: 0.4940
# Epoch 69/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0176 - mean_absolute_error: 0.1003 - val_loss: 0.4092 - val_mean_absolute_error: 0.4955
# Epoch 70/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0144 - mean_absolute_error: 0.0917 - val_loss: 0.4105 - val_mean_absolute_error: 0.4926
# Epoch 71/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0122 - mean_absolute_error: 0.0830 - val_loss: 0.4399 - val_mean_absolute_error: 0.5046
# Epoch 72/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0149 - mean_absolute_error: 0.0923 - val_loss: 0.4176 - val_mean_absolute_error: 0.5026
# Epoch 73/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0148 - mean_absolute_error: 0.0963 - val_loss: 0.4298 - val_mean_absolute_error: 0.5033
# Epoch 74/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0109 - mean_absolute_error: 0.0783 - val_loss: 0.4337 - val_mean_absolute_error: 0.5069
# Epoch 75/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0126 - mean_absolute_error: 0.0866 - val_loss: 0.4327 - val_mean_absolute_error: 0.5041
# Epoch 76/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0131 - mean_absolute_error: 0.0866 - val_loss: 0.4087 - val_mean_absolute_error: 0.4895
# Epoch 77/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0108 - mean_absolute_error: 0.0780 - val_loss: 0.4211 - val_mean_absolute_error: 0.4942
# Epoch 78/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0106 - mean_absolute_error: 0.0720 - val_loss: 0.4227 - val_mean_absolute_error: 0.4974
# Epoch 79/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0099 - mean_absolute_error: 0.0741 - val_loss: 0.4201 - val_mean_absolute_error: 0.4952
# Epoch 80/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0123 - mean_absolute_error: 0.0792 - val_loss: 0.4256 - val_mean_absolute_error: 0.4973
# Epoch 81/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0102 - mean_absolute_error: 0.0767 - val_loss: 0.4092 - val_mean_absolute_error: 0.4905
# Epoch 82/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0108 - mean_absolute_error: 0.0738 - val_loss: 0.4108 - val_mean_absolute_error: 0.4883
# Epoch 83/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0109 - mean_absolute_error: 0.0775 - val_loss: 0.4123 - val_mean_absolute_error: 0.4924
# Epoch 84/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0140 - mean_absolute_error: 0.0903 - val_loss: 0.4061 - val_mean_absolute_error: 0.4914
# Epoch 85/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0139 - mean_absolute_error: 0.0883 - val_loss: 0.4279 - val_mean_absolute_error: 0.5015
# Epoch 86/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0141 - mean_absolute_error: 0.0933 - val_loss: 0.4384 - val_mean_absolute_error: 0.5076
# Epoch 87/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0135 - mean_absolute_error: 0.0887 - val_loss: 0.4393 - val_mean_absolute_error: 0.5060
# Epoch 88/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0107 - mean_absolute_error: 0.0816 - val_loss: 0.4385 - val_mean_absolute_error: 0.5045
# Epoch 89/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0728 - val_loss: 0.4062 - val_mean_absolute_error: 0.4868
# Epoch 90/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0085 - mean_absolute_error: 0.0689 - val_loss: 0.4335 - val_mean_absolute_error: 0.5032
# Epoch 91/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0087 - mean_absolute_error: 0.0674 - val_loss: 0.4208 - val_mean_absolute_error: 0.4993
# Epoch 92/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0080 - mean_absolute_error: 0.0645 - val_loss: 0.4222 - val_mean_absolute_error: 0.4970
# Epoch 93/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0661 - val_loss: 0.4306 - val_mean_absolute_error: 0.4991
# Epoch 94/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0619 - val_loss: 0.4178 - val_mean_absolute_error: 0.4972
# Epoch 95/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0086 - mean_absolute_error: 0.0686 - val_loss: 0.4288 - val_mean_absolute_error: 0.4977
# Epoch 96/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0084 - mean_absolute_error: 0.0668 - val_loss: 0.4397 - val_mean_absolute_error: 0.5048
# Epoch 97/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0090 - mean_absolute_error: 0.0700 - val_loss: 0.4395 - val_mean_absolute_error: 0.5112
# Epoch 98/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0093 - mean_absolute_error: 0.0714 - val_loss: 0.4248 - val_mean_absolute_error: 0.4967
# Epoch 99/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0089 - mean_absolute_error: 0.0716 - val_loss: 0.4325 - val_mean_absolute_error: 0.4992
# Epoch 100/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0086 - mean_absolute_error: 0.0710 - val_loss: 0.4067 - val_mean_absolute_error: 0.4896
# Epoch 101/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0106 - mean_absolute_error: 0.0799 - val_loss: 0.4261 - val_mean_absolute_error: 0.5002
# Epoch 102/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0713 - val_loss: 0.4290 - val_mean_absolute_error: 0.4983
# Epoch 103/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0085 - mean_absolute_error: 0.0704 - val_loss: 0.4069 - val_mean_absolute_error: 0.4899
# Epoch 104/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0083 - mean_absolute_error: 0.0695 - val_loss: 0.4249 - val_mean_absolute_error: 0.4988
# Epoch 105/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0074 - mean_absolute_error: 0.0631 - val_loss: 0.4255 - val_mean_absolute_error: 0.4989
# Epoch 106/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0689 - val_loss: 0.4077 - val_mean_absolute_error: 0.4879
# Epoch 107/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0687 - val_loss: 0.4340 - val_mean_absolute_error: 0.4993
# Epoch 108/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0071 - mean_absolute_error: 0.0625 - val_loss: 0.4174 - val_mean_absolute_error: 0.4918
# Epoch 109/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0087 - mean_absolute_error: 0.0695 - val_loss: 0.4059 - val_mean_absolute_error: 0.4894
# Epoch 110/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0104 - mean_absolute_error: 0.0823 - val_loss: 0.4322 - val_mean_absolute_error: 0.5010
# Epoch 111/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0120 - mean_absolute_error: 0.0862 - val_loss: 0.4144 - val_mean_absolute_error: 0.4933
# Epoch 112/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0116 - mean_absolute_error: 0.0844 - val_loss: 0.4423 - val_mean_absolute_error: 0.4999
# Epoch 113/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0697 - val_loss: 0.4241 - val_mean_absolute_error: 0.4977
# Epoch 114/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0072 - mean_absolute_error: 0.0628 - val_loss: 0.4183 - val_mean_absolute_error: 0.4908
# Epoch 115/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0072 - mean_absolute_error: 0.0627 - val_loss: 0.4540 - val_mean_absolute_error: 0.5085
# Epoch 116/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0071 - mean_absolute_error: 0.0626 - val_loss: 0.4252 - val_mean_absolute_error: 0.4975
# Epoch 117/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0051 - mean_absolute_error: 0.0544 - val_loss: 0.4248 - val_mean_absolute_error: 0.4978
# Epoch 118/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0063 - mean_absolute_error: 0.0589 - val_loss: 0.4183 - val_mean_absolute_error: 0.4935
# Epoch 119/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0054 - mean_absolute_error: 0.0536 - val_loss: 0.4274 - val_mean_absolute_error: 0.4996
# Epoch 120/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0048 - mean_absolute_error: 0.0485 - val_loss: 0.4174 - val_mean_absolute_error: 0.4957
# Epoch 121/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0053 - mean_absolute_error: 0.0501 - val_loss: 0.4226 - val_mean_absolute_error: 0.4939
# Epoch 122/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0057 - mean_absolute_error: 0.0570 - val_loss: 0.4310 - val_mean_absolute_error: 0.5000
# Epoch 123/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0066 - mean_absolute_error: 0.0593 - val_loss: 0.4191 - val_mean_absolute_error: 0.4949
# Epoch 124/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0056 - mean_absolute_error: 0.0598 - val_loss: 0.4461 - val_mean_absolute_error: 0.5069
# Epoch 125/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0083 - mean_absolute_error: 0.0681 - val_loss: 0.4307 - val_mean_absolute_error: 0.5001
# Epoch 126/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0070 - mean_absolute_error: 0.0645 - val_loss: 0.4168 - val_mean_absolute_error: 0.4903
# Epoch 127/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0077 - mean_absolute_error: 0.0664 - val_loss: 0.4306 - val_mean_absolute_error: 0.4990
# Epoch 128/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0088 - mean_absolute_error: 0.0746 - val_loss: 0.4447 - val_mean_absolute_error: 0.5078
# Epoch 129/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0102 - mean_absolute_error: 0.0794 - val_loss: 0.4212 - val_mean_absolute_error: 0.4943
# Epoch 130/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0117 - mean_absolute_error: 0.0863 - val_loss: 0.4090 - val_mean_absolute_error: 0.4858
# Epoch 131/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0098 - mean_absolute_error: 0.0793 - val_loss: 0.4201 - val_mean_absolute_error: 0.4932
# Epoch 132/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0109 - mean_absolute_error: 0.0806 - val_loss: 0.4515 - val_mean_absolute_error: 0.5187
# Epoch 133/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0069 - mean_absolute_error: 0.0630 - val_loss: 0.4382 - val_mean_absolute_error: 0.4995
# Epoch 134/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0711 - val_loss: 0.4186 - val_mean_absolute_error: 0.4942
# Epoch 135/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0073 - mean_absolute_error: 0.0653 - val_loss: 0.4210 - val_mean_absolute_error: 0.4922
# Epoch 136/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0092 - mean_absolute_error: 0.0748 - val_loss: 0.4088 - val_mean_absolute_error: 0.4864
# Epoch 137/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0081 - mean_absolute_error: 0.0702 - val_loss: 0.4320 - val_mean_absolute_error: 0.4978
# Epoch 138/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0065 - mean_absolute_error: 0.0621 - val_loss: 0.4307 - val_mean_absolute_error: 0.4985
# Epoch 139/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0078 - mean_absolute_error: 0.0680 - val_loss: 0.4277 - val_mean_absolute_error: 0.4983
# Epoch 140/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0061 - mean_absolute_error: 0.0601 - val_loss: 0.4182 - val_mean_absolute_error: 0.4955
# Epoch 141/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0060 - mean_absolute_error: 0.0593 - val_loss: 0.4422 - val_mean_absolute_error: 0.5071
# Epoch 142/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0059 - mean_absolute_error: 0.0579 - val_loss: 0.4288 - val_mean_absolute_error: 0.5038
# Epoch 143/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0057 - mean_absolute_error: 0.0561 - val_loss: 0.4316 - val_mean_absolute_error: 0.4983
# Epoch 144/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0040 - mean_absolute_error: 0.0471 - val_loss: 0.4265 - val_mean_absolute_error: 0.4977
# Epoch 145/150
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0045 - mean_absolute_error: 0.0505 - val_loss: 0.4249 - val_mean_absolute_error: 0.4973
# Epoch 146/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0067 - mean_absolute_error: 0.0643 - val_loss: 0.4386 - val_mean_absolute_error: 0.5076
# Epoch 147/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0152 - mean_absolute_error: 0.0961 - val_loss: 0.4672 - val_mean_absolute_error: 0.5179
# Epoch 148/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0169 - mean_absolute_error: 0.1011 - val_loss: 0.4203 - val_mean_absolute_error: 0.4919
# Epoch 149/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0130 - mean_absolute_error: 0.0895 - val_loss: 0.4216 - val_mean_absolute_error: 0.4960
# Epoch 150/150
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0123 - mean_absolute_error: 0.0860 - val_loss: 0.4486 - val_mean_absolute_error: 0.5055

# %% [markdown]
# ### Evaluate accuracy and loss of your model. This is how your plots should look like:
# <table><tr>
# <td> <img src="images/accuracy.png" style="width: 500px;"/> </td>
# <td> <img src="images/loss.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# ### Now evaluate the predictions of your model in terms of RMSE and NRMSE. You should obtain plots like these:
# <table><tr>
# <td> <img src="images/inference.png" style="width: 500px;"/> </td>
# <td> <img src="images/inference_diff.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Prediction
pred = model.predict(X_test).reshape(1,-1)[0]

rmse = RMSE(y_test, pred)
nrmse = NRMSE(y_test, pred)


print("rmse : ",rmse,"  nrmse : ",nrmse)
# Out:
# 4/4 [==============================] - 0s 881us/step
# rmse :  0.5763046823728255   nrmse :  0.2853731413558524

# %%
my_x=np.arange(0,len(X_test[:,0]),1)

fig = plt.figure(figsize=(20,10))
plt.scatter(my_x, y_test, label='Real', color='blue', marker='o')
plt.scatter(my_x, pred, label='Inference', color='red', marker='s')
plt.title(f'Inference of log(NO2)  rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('log(NO2)')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
my_d = abs(y_test-pred)

plt.bar(my_x,my_d)
plt.title(f'Inference of log(NO2) -- absolute difference between inference and ground truth rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('absolute value of difference in inference [log(NO2)]')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.show()
